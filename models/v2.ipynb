# %%
import pandas as pd

games_df = pd.read_csv("../data/processed/v2.csv")
games_df
# Out:
#                win_name        lose_name win_color lose_color        date  \
# 0             Kato Shin  Sekiyama Riichi         b          w  1941-05-18
# 1       Sekiyama Riichi        Kato Shin         b          w  1941-05-27
# 2             Kato Shin  Sekiyama Riichi         b          w  1941-06-09
# 3       Sekiyama Riichi        Kato Shin         b          w  1941-06-21
# 4             Kato Shin  Sekiyama Riichi         b          w  1941-07-01
# ...                 ...              ...       ...        ...         ...
# 101404      Song Jihoon     Moon Minjong         w          b  2022-02-19
# 101405    Kim Sangcheon       Lee Hyunho         w          b  2022-02-19
# 101406      Shin Minjun    Lee Changseok         w          b  2022-02-19
# 101407     Lee Yeongkyu     Park Sangjin         w          b  2022-02-19
# 101408    Park Jinyoung      Kang Jihoon         b          w  2022-02-19
#
#        win_rank lose_rank  komi   PS   OS  streak       PWR       OWR
# 0            7p        6p   0.0  0.0  0.0     0.0  0.000000  0.000000
# 1            6p        7p   0.0 -1.0  1.0    -1.0  0.000000  1.000000
# 2            7p        6p   0.0 -1.0  1.0     1.0  0.500000  0.500000
# 3            6p        7p   0.0 -1.0  1.0    -1.0  0.333333  0.666667
# 4            7p        6p   0.0 -1.0  1.0     1.0  0.500000  0.500000
# ...         ...       ...   ...  ...  ...     ...       ...       ...
# 101404       7p        5p   6.5 -1.0 -4.0    -4.0  0.480663  0.505376
# 101405       4p        6p   6.5 -1.0  2.0    -1.0  0.576271  0.451613
# 101406       9p        8p   6.5 -1.0 -1.0    -1.0  0.568627  0.555066
# 101407       9p        6p   6.5  5.0  1.0     1.0  0.565561  0.511450
# 101408       5p        3p   6.5  3.0  1.0     3.0  0.444444  0.500000
#
# [101409 rows x 13 columns]

# %%
labeled_df = games_df.drop(['win_name', 'lose_name', 'date'], axis=1)
labeled_df = labeled_df.rename(columns={'win_color': 'player_color', 'lose_color': 'opponent_color', 'win_rank': 'player_rank', 'lose_rank': 'opponent_rank'})
labeled_df['target'] = 1

labeled_df
# Out:
#        player_color opponent_color player_rank opponent_rank  komi   PS   OS  \
# 0                 b              w          7p            6p   0.0  0.0  0.0
# 1                 b              w          6p            7p   0.0 -1.0  1.0
# 2                 b              w          7p            6p   0.0 -1.0  1.0
# 3                 b              w          6p            7p   0.0 -1.0  1.0
# 4                 b              w          7p            6p   0.0 -1.0  1.0
# ...             ...            ...         ...           ...   ...  ...  ...
# 101404            w              b          7p            5p   6.5 -1.0 -4.0
# 101405            w              b          4p            6p   6.5 -1.0  2.0
# 101406            w              b          9p            8p   6.5 -1.0 -1.0
# 101407            w              b          9p            6p   6.5  5.0  1.0
# 101408            b              w          5p            3p   6.5  3.0  1.0
#
#         streak       PWR       OWR  target
# 0          0.0  0.000000  0.000000       1
# 1         -1.0  0.000000  1.000000       1
# 2          1.0  0.500000  0.500000       1
# 3         -1.0  0.333333  0.666667       1
# 4          1.0  0.500000  0.500000       1
# ...        ...       ...       ...     ...
# 101404    -4.0  0.480663  0.505376       1
# 101405    -1.0  0.576271  0.451613       1
# 101406    -1.0  0.568627  0.555066       1
# 101407     1.0  0.565561  0.511450       1
# 101408     3.0  0.444444  0.500000       1
#
# [101409 rows x 11 columns]

# %%
reversed_df = labeled_df.copy(deep=True)
reversed_df = reversed_df.rename(columns={'player_color':'opponent_color', 'opponent_color':'player_color', 'player_rank':'opponent_rank', 'opponent_rank':'player_rank', 'PS': 'OS', 'OS':'PS', 'PWR': 'OWR', 'OWR':'PWR'})
reversed_df['target'] = 0

reversed_df
# Out:
#        opponent_color player_color opponent_rank player_rank  komi   OS   PS  \
# 0                   b            w            7p          6p   0.0  0.0  0.0
# 1                   b            w            6p          7p   0.0 -1.0  1.0
# 2                   b            w            7p          6p   0.0 -1.0  1.0
# 3                   b            w            6p          7p   0.0 -1.0  1.0
# 4                   b            w            7p          6p   0.0 -1.0  1.0
# ...               ...          ...           ...         ...   ...  ...  ...
# 101404              w            b            7p          5p   6.5 -1.0 -4.0
# 101405              w            b            4p          6p   6.5 -1.0  2.0
# 101406              w            b            9p          8p   6.5 -1.0 -1.0
# 101407              w            b            9p          6p   6.5  5.0  1.0
# 101408              b            w            5p          3p   6.5  3.0  1.0
#
#         streak       OWR       PWR  target
# 0          0.0  0.000000  0.000000       0
# 1         -1.0  0.000000  1.000000       0
# 2          1.0  0.500000  0.500000       0
# 3         -1.0  0.333333  0.666667       0
# 4          1.0  0.500000  0.500000       0
# ...        ...       ...       ...     ...
# 101404    -4.0  0.480663  0.505376       0
# 101405    -1.0  0.576271  0.451613       0
# 101406    -1.0  0.568627  0.555066       0
# 101407     1.0  0.565561  0.511450       0
# 101408     3.0  0.444444  0.500000       0
#
# [101409 rows x 11 columns]

# %%
processed_df = pd.concat([labeled_df,reversed_df], ignore_index=True)
processed_df = processed_df[(~processed_df['player_rank'].isin(['Ama.', 'Insei', 'NR'])) & (~processed_df['opponent_rank'].isin(['Ama.', 'Insei', 'NR']))]
processed_df['player_rank'] = processed_df['player_rank'].apply(lambda x: int(x[0]))
processed_df['opponent_rank'] = processed_df['opponent_rank'].apply(lambda x: int(x[0]))
processed_df['player_color'] = processed_df['player_color'].apply(lambda x: 1 if x == 'b' else 0)
processed_df['opponent_color'] = processed_df['opponent_color'].apply(lambda x: 1 if x == 'w' else 0)

processed_df
# Out:
#         player_color  opponent_color  player_rank  opponent_rank  komi   PS  \
# 0                  1               1            7              6   0.0  0.0
# 1                  1               1            6              7   0.0 -1.0
# 2                  1               1            7              6   0.0 -1.0
# 3                  1               1            6              7   0.0 -1.0
# 4                  1               1            7              6   0.0 -1.0
# ...              ...             ...          ...            ...   ...  ...
# 202813             1               1            5              7   6.5 -4.0
# 202814             1               1            6              4   6.5  2.0
# 202815             1               1            8              9   6.5 -1.0
# 202816             1               1            6              9   6.5  1.0
# 202817             0               0            3              5   6.5  1.0
#
#          OS  streak       PWR       OWR  target
# 0       0.0     0.0  0.000000  0.000000       1
# 1       1.0    -1.0  0.000000  1.000000       1
# 2       1.0     1.0  0.500000  0.500000       1
# 3       1.0    -1.0  0.333333  0.666667       1
# 4       1.0     1.0  0.500000  0.500000       1
# ...     ...     ...       ...       ...     ...
# 202813 -1.0    -4.0  0.505376  0.480663       0
# 202814 -1.0    -1.0  0.451613  0.576271       0
# 202815 -1.0    -1.0  0.555066  0.568627       0
# 202816  5.0     1.0  0.511450  0.565561       0
# 202817  3.0     3.0  0.500000  0.444444       0
#
# [201486 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

X, y = processed_df[['player_color', 'opponent_color', 'player_rank', 'opponent_rank', 'komi', 'PWR', 'OWR', 'PS', 'OS']], processed_df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# 0.5947153180338283

# %% [markdown]
# With new features: win rates and win streaks we got accuracy 3.7% increase.

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier()
clf.fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# 0.6194512824585087

# %% [markdown]
# With MLP we now get more accuracy. 6.4% better than RFC from v1.
