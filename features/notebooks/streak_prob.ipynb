# %% [markdown]
# ### Streak Probability
#
# For each player, record their probability of keeping a streak/if streak affects their current games
#
# How should I implement this...?
#
# PM: Player Momentum
# OM: Opponent Momentum

# %%
import pandas as pd

games_df = pd.read_csv("../../data/processed/data.csv")

games_df.sort_values(by=['date'], inplace=True, ignore_index=True)
games_df
# Out:
#                win_name        lose_name win_color lose_color        date  \
# 0             Kato Shin  Sekiyama Riichi         b          w  1941-05-18
# 1       Sekiyama Riichi        Kato Shin         b          w  1941-05-27
# 2             Kato Shin  Sekiyama Riichi         b          w  1941-06-09
# 3       Sekiyama Riichi        Kato Shin         b          w  1941-06-21
# 4             Kato Shin  Sekiyama Riichi         b          w  1941-07-01
# ...                 ...              ...       ...        ...         ...
# 101404      Jin Siyoung    Choi Kyeongho         w          b  2022-02-19
# 101405     Kang Dongyun     Seol Hyunjun         b          w  2022-02-19
# 101406       Kim Jiseok     Shin Jaeweon         w          b  2022-02-19
# 101407    Kim Changhoon     Kwak Wonkeun         b          w  2022-02-19
# 101408    Park Jinyoung      Kang Jihoon         b          w  2022-02-19
#
#        win_rank lose_rank  komi
# 0            7p        6p   0.0
# ...
