# %% [markdown]
# ## Data Processing
#
# Merge all initial raw data files into a single dataframe and csv

# %%
from os import listdir
import pandas as pd
from sgfmill.sgf import Sgf_game
from tqdm import tqdm

files = listdir("../data/raw")
games = []
for file in tqdm(files):
    file = "".join(["../data/raw/", file])
    with open(file, "rb") as f:
        game = Sgf_game.from_bytes(f.read())
        winner = game.get_winner()
        loser = 'w' if winner == 'b' else 'b'
        
        # Some files don't have a winner. Let's skip those.
        if not winner:
            continue
            
        games.append({
            'win_name': game.get_player_name(winner),
            'lose_name': game.get_player_name(loser),
            'win_color': winner,
            'lose_color': loser,
            'date': game.get_root().get('DT'),
            'win_rank': game.get_root().get(f'{winner.upper()}R'),
            'lose_rank': game.get_root().get(f'{loser.upper()}R'),
            'komi': game.get_root().get('KM')
        })
    
games_df = pd.DataFrame(games)
games_df
# Out:
# 100%|██████████| 101453/101453 [02:46<00:00, 610.00it/s]
#                    win_name        lose_name win_color lose_color        date  \
# 0               Lin Lixiang      Lin Xiuping         b          w  2020-01-14
# 1             Jian Jingting       Hei Jiajia         b          w  2018-03-19
# 2           Toyoda Hirohito    Aoki Hirotaka         b          w  2021-09-27
# 3       Shimamura Toshihiro  Hashimoto Utaro         w          b  1963-01-16
# 4                  Oh Yujin       Zhao Yifei         w          b  2018-08-14
# ...                     ...              ...       ...        ...         ...
# 101404             Gao Xing       Gu Wanshan         w          b  2021-09-27
# 101405         Kang Dongyun       Lin Junyan         b          w  2012-12-12
# 101406          Shin Jinseo    Park Junghwan         b          w  2020-10-22
# 101407           Wang Yuhui      Chen Linxin         b          w  1999-11-11
# 101408           Tao Xinran      Liao Yuanhe         w          b  2020-12-13
#
#        win_rank lose_rank  komi
# 0            7p        6p   6.5
# 1            3p        7p   6.5
# 2            1p        2p   6.5
# 3            9p        9p   4.5
# 4            6p        3p   7.5
# ...         ...       ...   ...
# 101404       4p        2p   7.5
# 101405       9p        3p   7.5
# 101406       9p        9p   6.5
# 101407       6p        9p   5.5
# 101408       8p        8p   7.5
#
# [101409 rows x 8 columns]

# %%
games_df.to_csv("../data/processed/data.csv", index=False)
